# %%
#type function
print(type([1,2,3]))
print(type(()))
# Out:
# <class 'list'>
# <class 'tuple'>

# %%
# abs function
print(abs(-4), abs(4))
print(abs(-4.6),abs(4.6))
print(abs(-3 + 4j),abs(3 + 4j))
# Out:
# 4 4
# 4.6 4.6
# 5.0 5.0

# %%
# bool function
print('Boolean values : ',bool(True),bool(False))
print('Empty iterables :',bool([]),bool(()),bool({}))
print(bool(0.0000000001))
# Out:
# Boolean values :  True False
# Empty iterables : False False False
# True

# %%
# int function
print(int('25'))
print(int('1001',2)) # the giiven string 1001 is in base(2) format
print(int('12',8)) # the giiven string 12 is in base(8) format
# Out:
# 25
# 9
# 10

# %%
# input function
a = input()
print(a)
a = input("Enter a  value: ")
print(a)
# Out:
# Hello
# Enter a  value: Hi
# Hi

# %%
# max and min
print(max('abc'),max([1,2,3]),max((10,20,15))) # Returns maximum of all arguments
print(min('abc'),min([1,2,3]),min((10,20,15))) # Returns minimum of all arguments
# Out:
# c 3 20
# a 1 10

# %%
# Keywords
# False True 
a = True # Assign to a variable
str1 = 'abc'
str2 = 'def'
print(a, str1 == str2)
# Out:
# True False

# %%
# None Keyword
a = None
a

# %%
# if elif else
x = 10
if x < 10:
    print('lesser than 10')
elif x > 10:
    print('Greater than 10')
else:
    print('is 10')
# Out:
# is 10

# %%
# and or not
print(0 and 1)
print(0 or 1)
print(not 0)
# Out:
# 0
# 1
# True

# %%
# Identifiers
myVar_1 = 10
myVar_1
# Out:
# 10

# %%
# Identifiers
1_var_mine = 10
# Out:
#   File "<ipython-input-2-d7dee6ffbd42>", line 2
#     1_var_mine = 10
#      ^
# SyntaxError: invalid token

# %%
a@ = 10
# Out:
#   File "<ipython-input-3-adceaddf80c5>", line 1
#     a@ = 10
#        ^
# SyntaxError: invalid syntax

# %%
# data types
#int
a = 10
type(a)
# Out:
# int

# %%
# float
a = 1.999999999999999
type(a)
# Out:
# float

# %%
# complex
a = 1 + 2j
type(a)
# Out:
# complex

# %%
# strings
a = 'This is a string'
a
# Out:
# 'This is a string'

# %%
# strings 
a = 'abcd'
a[0]
# Out:
# 'a'

# %%
a = 'abcd'
a[0] = 'f'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-88b182281d56> in <module>
#       1 a = 'abcd'
# ----> 2 a[0] = 'f'
#
# TypeError: 'str' object does not support item assignment

# %%
# Tuples
a = (1,2,3,4,5)
a
# Out:
# (1, 2, 3, 4, 5)

# %%
# Tuples
a[0] = 10
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-392115a6b556> in <module>
#       1 # Tuples
# ----> 2 a[0] = 10
#
# TypeError: 'tuple' object does not support item assignment

# %%
# sets
a = {1,2,3,4,4}
a
# Out:
# {1, 2, 3, 4}

# %%
a[0] = 2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-fa1ba3f7cc8f> in <module>
# ----> 1 a[0] = 2
#
# NameError: name 'a' is not defined

# %%
# Lists
a = [1,2,3,4]
a
# Out:
# [1, 2, 3, 4]

# %%
a[0] = 10
a
# Out:
# [10, 2, 3, 4]

# %%
# Dictionarries
a = {1 :  'a', 2 : 'b', 3 : 'c'}
a
# Out:
# {1: 'a', 2: 'b', 3: 'c'}

# %%
a[1]
# Out:
# 'a'

# %%
a.values()
# Out:
# dict_values(['a', 'b', 'c'])

# %%
a.keys()
# Out:
# dict_keys([1, 2, 3])
